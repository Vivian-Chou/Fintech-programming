# %% [markdown]
# ### 匯入套件

# %%
from lxml import etree
import requests
import json
import pandas as pd

# %% [markdown]
# ### 運算過程

# %%
def get_all_api():
    alljson=[]
    for page in range(1,5):
        apilink="https://fund.api.cnyes.com/fund/api/v2/search/fund?order=priceDate&sort=desc&page="+str(page)+"&institutional=0&isShowTag=1&fields=categoryAbbr,change,changePercent,classCurrencyLocal,cnyesId,displayNameLocal,displayNameLocalWithKwd,forSale,forSale,inceptionDate,investmentArea,lastUpdate,nav,prevPrice,priceDate,return1Month"
        res = requests.get(apilink)
        resjson=json.loads(res.text)
        alljson.append(resjson['items']['data'])
    return alljson
def totalpage():
    link = 'https://fund.cnyes.com/search/'
    res = requests.get(link)
    raw_data = etree.HTML(res.content.decode('utf-8'))
    totalpage="".join(raw_data.xpath("//strong[@data-reactid='579']/text()"))
    if int(totalpage)%20==0:
        totalpage=int(totalpage)/20
    else:
        totalpage=(int(totalpage)//20)+1
    return totalpage+1
def fitdf():
    dfa = pd.DataFrame.from_dict(get_all_api()[0])
    for pagejson in range(1,len(get_all_api())):
        dfb = pd.DataFrame.from_dict(get_all_api()[pagejson])
        dfa = pd.concat([dfa, dfb], axis= 0)
    dfa = dfa.reset_index(drop=True)
    return dfa

# %% [markdown]
# ### to csv

# %%
df = pd.DataFrame(fitdf())
df.to_csv('fund0320.csv',encoding = 'utf-8')

# %%
df
# Out:
#     cnyesId       nav  forSale  change fundYesId investmentArea  \
# 0   B16,009   30.5400        1 -0.1500    B16009       歐洲(含歐元區)
# 1   B16,013   20.8200        1 -0.0600    B16013       歐洲(含歐元區)
# 2   B16,019  104.5000        1 -3.1600    B16019           全球市場
# 3   B16,137   94.7000        1 -0.4000    B16137         中國/大中華
# 4   B23,258    5.5848        0  0.0018      None           亞洲地區
# ..      ...       ...      ...     ...       ...            ...
# 75  B05,016   25.4096        1 -0.2453    B05016           全球市場
# 76  B05,003  607.8446        1 -2.0840    B05003             日本
# 77  B05,014   28.7221        1 -0.1228    B05014             英國
# 78  B05,001   16.6678        1  0.0030    B05001         全球新興市場
# 79  B05,011   50.8500        1 -0.2035    B05011         澳洲/大洋洲
#
#      categoryAbbr  prevPrice          displayNameLocal   priceDate  \
# 0            歐洲股票    30.6900            景順全歐洲企業基金A股 歐元  1616083200
# 1            歐洲股票    20.8800              景順泛歐洲基金A股 歐元  1616083200
# 2   產業股票 - 消費品及服務   107.6600           景順環球消費趨勢基金A股 美元  1616083200
# 3           大中華股票    95.1000              景順大中華基金A股 美元  1616083200
# 4            亞洲債券     5.5830  施羅德環球基金系列－亞洲債券(美元)A-月配浮動  1616083200
# ..            ...        ...                       ...         ...
# 75           全球股票    25.6549     安本標準 - 世界股票基金 A 累積 美元  1616083200
# 76           日本股票   609.9286     安本標準 - 日本股票基金 A 累積 日圓  1616083200
# 77           英國股票    28.8449     安本標準 - 英國股票基金 A 累積 英鎊  1616083200
# 78          新興市場債    16.6648  安本標準 - 新興市場債券基金 A 月配息 美元  1616083200
# 79           紐澳股票    51.0535     安本標準 - 澳洲股票基金 A 累積 澳幣  1616083200
#
#     inceptionDate  lastUpdate classCurrencyLocal  changePercent  return1Month  \
# 0       662745600  1616112000                 歐元          -0.49       0.16399
# 1       662659200  1616112000                 歐元          -0.29       6.38733
# 2       781113600  1616112000                 美元          -2.94      -3.74873
# 3       711129600  1616112000                 美元          -0.42      -9.76656
# 4       908467200  1616083200                 美元           0.03      -2.18221
# ..            ...         ...                ...            ...           ...
# 75      728496000  1616112000                 美元          -0.96      -2.40890
# 76      577987200  1616112000                 日圓          -0.34       0.02626
# 77      577900800  1616112000                 英鎊          -0.43      -1.53751
# 78      997804800  1616112000                 美元           0.02      -2.38050
# 79      577987200  1616112000                 澳元          -0.40      -0.96580
#
#     displayNameLocalWithKwd  \
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ..                      ...
# 75                        0
# 76                        0
# 77                        0
# 78                        0
# 79                        0
#
#                                            forSaleUrl  \
# 0   https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 1   https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 2   https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 3   https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 4
# ..                                                ...
# 75  https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 76  https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 77  https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 78  https://www.anuefund.com/Redr/Redr.aspx?FundID...
# 79  https://www.anuefund.com/Redr/Redr.aspx?FundID...
#
#                                              fundTags  \
# 0   [{'promoteName': '景順全系列0申購手續費', 'promoteDescri...
# 1   [{'promoteName': '景順全系列0申購手續費', 'promoteDescri...
# 2   [{'promoteName': '景順全系列0申購手續費', 'promoteDescri...
# 3   [{'promoteName': '景順全系列0申購手續費', 'promoteDescri...
# 4                                                  []
# ..                                                ...
# 75                                                 []
# 76                                                 []
# 77  [{'promoteName': '晨星評等', 'promoteDescription':...
# 78  [{'promoteName': '2021債券、平衡、股票月配級別申購0手續費', 'pr...
# 79  [{'promoteName': '晨星評等', 'promoteDescription':...
#
#                                    portfolio_errors
# 0   {"message":"Token not found","status_code":400}
# 1   {"message":"Token not found","status_code":400}
# 2   {"message":"Token not found","status_code":400}
# 3   {"message":"Token not found","status_code":400}
# 4   {"message":"Token not found","status_code":400}
# ..                                              ...
# 75  {"message":"Token not found","status_code":400}
# 76  {"message":"Token not found","status_code":400}
# 77  {"message":"Token not found","status_code":400}
# 78  {"message":"Token not found","status_code":400}
# 79  {"message":"Token not found","status_code":400}
#
# [80 rows x 19 columns]
