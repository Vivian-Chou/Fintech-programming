# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('基金0501.csv',index_col="Unnamed: 0")

# %%
pd.set_option('display.max_columns', None)#顯示所有col

# %%
df = df.replace('--', 'NaN').replace('--%','NaN')

# %%
def splitpercent(target):
    target = target.apply(lambda x:float(x.split("%")[0])*0.01)
    return target

# %%
for col in df.columns[17:33]:
    df[col] = splitpercent(df[col])
for col in df.columns[41:49]:
    df[col] = splitpercent(df[col])
for col in df.columns[77:80]:
    df[col] = splitpercent(df[col])

# %%
n = 0
values = list(x for x in df.columns)
for col in values[17:25]:    
    df[str(col.split("-")[1])+'diff'] =  df[values[6+n]].astype(float)-df[values[17+n]].astype(float)
    n+=1

# %%
df.to_csv('OP基金0501.csv',encoding = 'utf-8')

# %%
df = pd.read_csv('OP基金0501.csv',index_col="Unnamed: 0")

# %%
pd.set_option('display.max_columns', None)

# %%
delcol = ['更新日期','一周績效','一月績效','三月績效','六月績效','今年以來績效','一年績效','兩年績效','三年績效','五年績效','十年績效','績效表現','風險評估','基準指數-1月','基準指數-3月','基準指數-6月','基準指數-今年以來','基準指數-1年','基準指數-3年','基準指數-5年','基準指數-10年','夏普值-1月','夏普值-3月','夏普值-6月','夏普值-今年以來','夏普值-10年','Beta值-1月','Beta值-3月','Beta值-6月','Beta值-今年以來','Beta值-10年','r square-1月','r square-3月','r square-6月','r square-今年以來','r square-1年','r square-5年','r square-10年','標準差-1月','標準差-3月','標準差-6月','標準差-今年以來','標準差-10年','Alpha-1月','Alpha-3月','Alpha-6月','Alpha-今年以來','Alpha-1年','Alpha-5年','Alpha-10年']
df = df.drop(columns=delcol, axis=1)

# %%
#原本績效跟基準指數的欄位刪掉，然後夏普值、Beta值、標準差排名，diff也排名差異越大排名越前
#然後沒有資料的欄位全部刪掉

# %%
df["夏普值-1年Rank"] = df["夏普值-1年"].rank()
df["夏普值-3年Rank"] = df["夏普值-3年"].rank()
# df["夏普值-5年Rank"] = df["夏普值-5年"].rank()
df["Beta值-1年Rank"] = df["Beta值-1年"].rank()
df["Beta值-3年Rank"] = df["Beta值-3年"].rank()
# df["Beta值-5年Rank"] = df["Beta值-5年"].rank()
df["標準差-1年Rank"] = df["標準差-1年"].rank()
df["標準差-3年Rank"] = df["標準差-3年"].rank()
# df["標準差-5年Rank"] = df["標準差-5年"].rank()
df["Alpha-3年Rank"] = df["Alpha-3年"].rank()

df["1月Rank"] = df["1月diff"].rank()
df["3月Rank"] = df["3月diff"].rank()
df["6月Rank"] = df["6月diff"].rank()
df["今年以來Rank"] = df["今年以來diff"].rank()
df["1年Rank"] = df["1年diff"].rank()
df["3年Rank"] = df["3年diff"].rank()
# df["5年Rank"] = df["5年diff"].rank()
# df["10年Rank"] = df["10年diff"].rank()

df["SUM"] = df.iloc[:,47:].sum(axis=1)
df["SUM"] = df["SUM"].apply(lambda x:x+df['Alpha-3年Rank']*0.5)
df["AVG"] = df["SUM"]/(12.5-df.iloc[:,47:].isnull().sum(axis=1))
df["RANK"] = df["AVG"].rank(ascending=False)

# %%
df
# Out:
#       基金ID    最新淨值  漲跌(%)       基金名稱  同組平均-1月  同組平均-3月  同組平均-6月  同組平均-今年以來  \
# 0   A14010   27.87   0.51   新光創新科技基金   0.0556   0.0459   0.2739     0.0861
# 1  A1SsohV   15.38   0.09  合庫台灣高科技基金   0.0556   0.0459   0.2739     0.0861
# 2   A33001   24.20   0.18   聯邦精選科技基金   0.0556   0.0459   0.2739     0.0861
# 3   A19013   48.27   0.66   兆豐國際電子基金   0.0556   0.0459   0.2739     0.0861
# 4   A11004  107.30   0.93   摩根新興科技基金   0.0556   0.0459   0.2739     0.0861
#
#    同組平均-1年  同組平均-3年  同組平均-5年  同組平均-10年 同組排名-1月 同組排名-3月 同組排名-6月 同組排名-今年以來  \
# 0   0.6148    0.812   1.6694    2.9023   1/156   1/152   1/137     1/149
# 1   0.6148    0.812   1.6694    2.9023   2/156   8/152   2/137     3/149
# 2   0.6148    0.812   1.6694    2.9023   3/156   3/152  14/137     5/149
# 3   0.6148    0.812   1.6694    2.9023   4/156   2/152   7/137     2/149
# 4   0.6148    0.812   1.6694    2.9023   5/156  14/152   9/137    15/149
#
#   同組排名-1年 同組排名-3年 同組排名-5年 同組排名-10年  贏過N%基金-1月  贏過N%基金-3月  贏過N%基金-6月  \
# ...

# %%
df.to_csv('RANK0515.csv',encoding = 'utf-8')
